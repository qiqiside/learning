# %%
from common import Sort

# %%
class BottomUpMergeSort(Sort):
    
    def __init__(self, A = []):
        super(BottomUpMergeSort, self).__init__(A)
    
    def merge(self, lo, mid, hi):
        # merge A[lo..mid] and A[mid+1..hi]
        A = self.A
        aux = self.aux
        
        for k in range(lo, hi + 1):
            aux[k] = A[self.start + k]
        
        i = lo
        j = mid + 1
        
        for k in range(lo, hi + 1):
            if i > mid:
                A[self.start + k] = aux[j]
                j += 1
            elif j > hi:
                A[self.start + k] = aux[i]
                i += 1
            elif aux[j] < aux[i]:
                A[self.start + k] = aux[j]
                j += 1
            else:
                A[self.start + k] = aux[i]
                i += 1
        
    def _sort(self):
        self.aux = [ None for x in range(self.end - self.start + 1)]
        
        A = self.A
        N = self.end - self.start + 1
        
        sz = 1
        while sz < N:            
            for lo in range(0, N - sz, sz + sz):
                self.merge(lo, lo + sz - 1, min(lo + sz + sz - 1, N - 1))
            
            sz *= 2
            
        return self.A

# %%
BottomUpMergeSort().verify()
# Out:
#   verify = True
#   verify = True
#   verify = True
#   verify = True
#   verify = True
#   verify = True
#   verify = True
#   verify = True
#   verify = True
#   verify = True
#   verify = True
